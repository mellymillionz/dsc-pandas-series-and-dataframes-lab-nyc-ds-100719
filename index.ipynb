# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
# def contains_n(text):
#     if 'N' in text:
#         return True
#     else:
#         return False

# # Or the shorter, more pythonic way
# def contains_n(text):
#     bool_val = 'N' in text
#     return bool_val

# %% [markdown]
# Rename all the columns to lower case:

# %%
# Rename all the columns to lower case

# columns = list(df)
# for column in columns:
#     print (df[column][0])

#df.apply(np.sum, axis=0) - #This function sums the columb axis
df = pd.read_csv('turnstile_180901.txt')

df.columns = map(str.lower, df.columns)

#df.columns

#df.columns = [df.map(str.lower(), df.columns)]
                   
df.head(5)
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
#Use the parameter inplace=True to set the current DataFrame index.

df.set_index('linename',inplace=True)
#df.head()

# %% [markdown]
# Remove the index:

# %%
# Remove the index
#When we reset the index, the old index is added as a column, and a new sequential index is used:

df.reset_index()
#df.head()
# Out:
#        linename    c/a  unit       scp        station division        date  \
# 0       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 1       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 2       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 3       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 4       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 5       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 6       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 7       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 8       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 9       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 10      NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# ...

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df = pd.read_csv('turnstile_180901.txt')


df['NUM_LINES'] = df['LINENAME'].map(lambda string: len(string))

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    cleaned = []
    for col in col_name:
        cleaned.append(col.lower().strip())
    # Clean the column name in any way you want to. Hint: think back to str methods 
    return cleaned

#df.columns = map(str.lower, df.columns)

# %%
# Use the above function to clean the column names
df.columns = clean(df.columns)

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'num_lines'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date

df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y')

#df['date'][0]
# Add a new column 'day_of_week' that represents the day of the week 

df['day_of_week'] = df['date'].dt.day_name()
#convert to a datatime(dt) object which has the method day_name()

df
# Out:
#           c/a  unit       scp        station linename division       date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-25
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-25
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-25
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-25
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-25
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-25
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-26
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-26
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-26
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-26
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-26
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-08-26
# ...

# %%
# Group the data by day of week and plot the sum of the numeric columns
sum_columns = df.groupby('day_of_week').aggregate('sum')

# grouped = df.groupby('day_of_week').sum()
#grouped.plot(kind='barh')
# plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped = df.reset_index()

# Print the first five rows of grouped
grouped.head()
# Out:
#    index   c/a  unit       scp station linename division       date      time  \
# 0      0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1      1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2      2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3      3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4      4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  num_lines day_of_week
# 0  REGULAR  6736067  2283184          7    Saturday
# 1  REGULAR  6736087  2283188          7    Saturday
# 2  REGULAR  6736105  2283229          7    Saturday
# 3  REGULAR  6736180  2283314          7    Saturday
# 4  REGULAR  6736349  2283384          7    Saturday

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {'Monday':False, 'Tuesday':False, 'Wednesday':False, 'Thursday':False, 'Friday':False, 'Saturday':True, 'Sunday':True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map

#df['LINENAME'].map(lambda string: len(string))

grouped['is_weekend'] = grouped['day_of_week'].map(weekend_map)

grouped.is_weekend
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 197595    False
# 197596    False
# 197597    False
# 197598    False
# 197599    False
# 197600    False
# 197601    False
# 197602    False
# 197603    False
# 197604    False
# 197605    False
# 197606    False
# 197607    False
# 197608    False
# 197609    False
# 197610    False
# 197611    False
# 197612    False
# 197613    False
# 197614    False
# 197615    False
# 197616    False
# 197617    False
# 197618    False
# ...

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').mean()
wkend[['entries', 'exits']].plot(kind='barh') #kind=barh means bar is horizontal 
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns

df = df.drop('c/a', axis=1) 
df.head()

df = df.drop('scp', axis=1)
df.head(2)
# Out:
#    unit station linename division       date      time     desc  entries  \
# 0  R051   59 ST  NQR456W      BMT 2018-08-25  00:00:00  REGULAR  6736067
# 1  R051   59 ST  NQR456W      BMT 2018-08-25  04:00:00  REGULAR  6736087
#
#      exits  num_lines day_of_week is_weekend
# 0  2283184          7    Saturday        NaN
# 1  2283188          7    Saturday        NaN

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here 
If you use sum its confusing because there are way more weekdays. Mean is a better comparison.

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
